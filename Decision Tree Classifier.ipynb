# %% [markdown]
# # step-1 Import Libraries

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %% [markdown]
# # step-2 Create Dataset

# %%
data = {
    "Outlook": ["Sunny", "Sunny", "Overcast", "Rain", "Rain", "Overcast"],
    "Humidity": ["High", "High", "High", "Normal", "Normal", "Normal"],
    "Wind": ["Weak", "Strong", "Weak", "Weak", "Strong", "Strong"],
    "Play": ["No", "No", "Yes", "Yes", "No", "Yes"]
}

df = pd.DataFrame(data)
print(df)

# %% [markdown]
# # Encode the data

# %%
le=LabelEncoder()
for col in df.columns:
    df[col]=le.fit_transform(df[col])
print("\nEncoded Data:/n",df)
# Out:
# Encoded Data:/n    Outlook  Humidity  Wind  Play
# 0        2         0     1     0
# 1        2         0     0     0
# 2        0         0     1     1
# 3        1         1     1     1
# 4        1         1     0     0
# 5        0         1     0     1

# %%
x=df.drop("Play",axis=1)
y=df["Play"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train
# Out:
#    Outlook  Humidity  Wind
# 5        0         1     0
# 2        0         0     1
# 4        1         1     0
# 3        1         1     1

# %%
model=DecisionTreeClassifier(criterion="entropy")
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred=model.predict(x_test)
print("Predictions:",y_pred)
# Out:
# Predictions: [1 0]

# %%
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.5

# %%
new_data=pd.DataFrame([[2,1,1,]],columns=x.columns)
prediction=model.predict(new_data)

print("New Data Prediction:","Yes" if prediction[0]==1 else "No")
# Out:
# New Data Prediction: Yes

# %%
importances=model.feature_importances_
for feature,importances in zip(x.columns,importances):
    print(f"{feature}:{importances:.3f}")
# Out:
# Outlook:0.616
# Humidity:0.000
# Wind:0.384

# %%
plt.figure(figsize=(12,6))
plot_tree(
model,
feature_names=x.columns,
class_names=["No","Yes"],
filled=True
)
plt.show()
